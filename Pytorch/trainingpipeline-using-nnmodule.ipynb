# %%
# create model class 

import torch 
import torch.nn as nn

# you are interhiting from the base class. nn.Module has everything. It has all functionalities 

class Model(nn.Module):
    def __init__(self, num_features):
        super().__init__()
