# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1'] = [1,1,0,0]
or_data['input2'] = [1,0,1,0]
or_data['output'] = [1,1,1,0]

# %%
and_data['input1'] = [1,1,0,0]
and_data['input2'] = [1,0,1,0]
and_data['output'] = [1,0,0,0]

# %%
xor_data['input1'] = [1,1,0,0]
xor_data['input2'] = [1,0,1,0]
xor_data['output'] = [0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
sns.scatterplot(
    x='input1',
    y='input2',
    hue='output',
    s=200,
    data=and_data
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
or_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(
    x = 'input1',
    y = 'input2',
    hue = 'output',
    s = 200,
    data = or_data
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
xor_data
# Out:
#    input1  input2  output
# 0       1       1       0
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(
    x = 'input1',
    y = 'input2',
    hue = 'output',
    s = 200,
    data = xor_data
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron

m1 = Perceptron()
m2 = Perceptron()
m3 = Perceptron()

# %%
m1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
m2.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
m3.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
print(m1.coef_)
print(m1.intercept_)
# Out:
# [[2. 2.]]
# [-2.]

# %%
x = np.linspace(-1,1,5)
y = -x+1

# %%
plt.plot(x,y)
sns.scatterplot(
    x='input1',
    y='input2',
    hue='output',
    s=200,
    data=and_data
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
print(m3.coef_)
print(m3.intercept_)
# Out:
# [[2. 2.]]
# [-1.]

# %%
x1 = np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(
    x = 'input1',
    y = 'input2',
    hue = 'output',
    s = 200,
    data = or_data
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
print(m2.coef_)
print(m2.intercept_)
# Out:
# [[0. 0.]]
# [0.]

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values,clf=m2,legend=2)
# Out:
# <Axes: >

# %% [markdown]
# Xor data cant be divided using single line

# %% [markdown]
# Problem with Perceptron is that it doesnt converge in Non-linear data
